# %% [markdown]
# <a href="https://colab.research.google.com/github/cbonnin88/Compensation_Analysis/blob/main/compensation_analyst_paystub_UK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re as r
import polars as pl
import plotly.express as px
from google.colab import auth
import gspread
from google.auth import default
from gspread_dataframe import set_with_dataframe

# %%
uk_payslip = """
Pay Statement
Private and Confidential
Innovate Analytics Ltd.
123 Tech Avenue, London, EC1R 0AT

Employee Details
Name: John Smith
Address: 456 Data Drive, London, SW1A 0AA
NI Number: QQ 12 34 56 A
Payroll No: 78910

Pay Period Details
Pay Date: 28/07/2025
Tax Period: 04
Tax Code: 1257L
PAYE Ref: 123/AB45678

Payments
Basic Pay: £4,583.33
Gross Pay: £4,583.33

Deductions
Income Tax: £707.17
National Insurance: £282.87
Pension (Employee): £229.17
Total Deductions: £1,219.21

Net Pay: £3,364.12

Year to Date Summary
Gross Pay YTD: £18,333.32
Taxable Pay YTD: £14,145.32
Tax Paid YTD: £2,828.68
NI Paid YTD: £1,131.48
"""

# %%
# Creating my regex patterns to extract the relative information
patterns = {
    'name':r'Name: \s*(.*)',
    'pay_date':r'Pay Date:\s*([\d/]+)',
    'basic_pay':r'Basic Pay:\s*£([\d,]+\.\d{2})',
    'gross_pay':r'Gross Pay:\s*£([\d,]+\.\d{2})',
    'income_tax':r'Income Tax:\s*£([\d,]+\.\d{2})',
    'national_insurance':r'National Insurance:\s*£([\d,]+\.\d{2})',
    'pension_employee':r'Pension \(Employee\):\s*£([\d,]+\.\d{2})',
    'net_pay':r'Net Pay:\s*£([\d,]+\.\d{2})',
    'gross_pay_ytd':r'Gross Pay YTD:\s*£([\d,]+\.\d{2})',
    'tax_paid_ytd':r'Tax Paid YTD:\s*£([\d,]+\.\d{2})'
}

pay_data = {k: r.search(v,uk_payslip).group(1) if r.search(v,uk_payslip) else None for k, v in patterns.items()}

# %%
# Creating the dataframe for the pay stub with Python Polars library
df_uk_pay = pl.DataFrame([pay_data])
df_uk_pay = df_uk_pay.with_columns([
    pl.col(col).str.replace_all(',','').cast(pl.Float64)
    for col in df_uk_pay.columns if col not in ['name','pay_date']
])

display(df_uk_pay)
# Out:
# shape: (1, 10)
# ┌───────┬─────────────┬───────────┬───────────┬───┬────────────┬─────────┬────────────┬────────────┐
# │ name  ┆ pay_date    ┆ basic_pay ┆ gross_pay ┆ … ┆ pension_em ┆ net_pay ┆ gross_pay_ ┆ tax_paid_y │
# │ ---   ┆ ---         ┆ ---       ┆ ---       ┆   ┆ ployee     ┆ ---     ┆ ytd        ┆ td         │
# │ str   ┆ str         ┆ f64       ┆ f64       ┆   ┆ ---        ┆ f64     ┆ ---        ┆ ---        │
# │       ┆             ┆           ┆           ┆   ┆ f64        ┆         ┆ f64        ┆ f64        │
# ╞═══════╪═════════════╪═══════════╪═══════════╪═══╪════════════╪═════════╪════════════╪════════════╡
# │ John  ┆ 28/07/2025  ┆ 4583.33   ┆ 4583.33   ┆ … ┆ 229.17     ┆ 3364.12 ┆ 18333.32   ┆ 2828.68    │
# │ Smith ┆             ┆           ┆           ┆   ┆            ┆         ┆            ┆            │
# └───────┴─────────────┴───────────┴───────────┴───┴────────────┴─────────┴────────────┴────────────┘

# %% [markdown]
# # **Adding Extra Calculations**

# %%
df_uk_pay = df_uk_pay.with_columns([
    ((pl.col('income_tax') / pl.col('gross_pay')) * 100).alias('tax_rate_pct').round(1),
    ((pl.col('national_insurance') / pl.col('gross_pay'))* 100).alias('ni_rate_pct').round(1),
    ((pl.col('pension_employee') / pl.col('gross_pay')) * 100).alias('pension_rate_pct').round(1)
])

df_uk_pay
# Out:
# shape: (1, 13)
# ┌───────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ name  ┆ pay_date   ┆ basic_pay  ┆ gross_pay  ┆ … ┆ tax_paid_ ┆ tax_rate_ ┆ ni_rate_p ┆ pension_r │
# │ ---   ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ytd       ┆ pct       ┆ ct        ┆ ate_pct   │
# │ str   ┆ str        ┆ f64        ┆ f64        ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │       ┆            ┆            ┆            ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ John  ┆ 28/07/2025 ┆ 4583.33    ┆ 4583.33    ┆ … ┆ 2828.68   ┆ 15.4      ┆ 6.2       ┆ 5.0       │
# │ Smith ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆           │
# └───────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# # **Deductions Chart**

# %%
deductions = {
    'Income Tax': df_uk_pay['income_tax'][0],
    'National Insurance':df_uk_pay['national_insurance'][0],
    'Pension':df_uk_pay['pension_employee'][0]
}

display(deductions)
# Out:
# {'Income Tax': 707.17, 'National Insurance': 282.87, 'Pension': 229.17}

# %%
fig_deductions = px.pie(
    names=list(deductions.keys()),
    values=(deductions.values()),
    title='Deductions Breakdown',
    color=list(deductions.keys()),
    color_discrete_sequence=px.colors.sequential.Viridis_r
)

fig_deductions.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4fd96ada-2b91-4a26-8178-4e8d92b7640b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fd96ada-2b91-4a26-8178-4e8d92b7640b")) {                    Plotly.newPlot(                        "4fd96ada-2b91-4a26-8178-4e8d92b7640b",                        [{"customdata":[["Income Tax"],["National Insurance"],["Pension"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cbr\u003ecolor=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Income Tax","National Insurance","Pension"],"legendgroup":"","marker":{"colors":["#fde725","#b5de2b","#6ece58"]},"name":"","showlegend":true,"values":[707.17,282.87,229.17],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{" ...

# %% [markdown]
# # **Gross Pay vs Total Deductions**

# %%
df_plot = df_uk_pay.with_columns(
    (pl.col('income_tax') + pl.col('national_insurance') + pl.col('pension_employee')).alias('total_deductions')
).to_pandas()

display(df_plot)
# Out:
#          name    pay_date  basic_pay  gross_pay  income_tax  \
# 0  John Smith  28/07/2025    4583.33    4583.33      707.17
#
#    national_insurance  pension_employee  net_pay  gross_pay_ytd  tax_paid_ytd  \
# 0              282.87            229.17  3364.12       18333.32       2828.68
#
#    tax_rate_pct  ni_rate_pct  pension_rate_pct  total_deductions
# 0          15.4          6.2               5.0           1219.21

# %%
df_plot = df_plot.rename(columns={
    'gross_pay':'Gross Pay',
    'total_deductions':'Total Deductions'
})

fig_bar = px.bar(
    df_plot,
    x='pay_date',
    y=['Gross Pay','Total Deductions'],
    barmode='group',
    title='Gross Pay vs Total Deductions',
    labels={'value':'Amount (£)',
           'pay_date':'Pay Date'},
    color_discrete_sequence=px.colors.qualitative.Pastel,
    text_auto=True
)
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="01a9fc3d-2aae-45c4-9f4b-f09f5c53cbff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01a9fc3d-2aae-45c4-9f4b-f09f5c53cbff")) {                    Plotly.newPlot(                        "01a9fc3d-2aae-45c4-9f4b-f09f5c53cbff",                        [{"alignmentgroup":"True","hovertemplate":"variable=Gross Pay\u003cbr\u003ePay Date=%{x}\u003cbr\u003eAmount (£)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gross Pay","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Gross Pay","offsetgroup":"Gross Pay","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[4583.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Total Deductions\u003cbr\u003ePay Date=%{x}\u003cbr\u003eAmount (£)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Total Deductions","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Total Deductions","offsetgroup":"Total Deductions","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[1219.21],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# # **Breakdown of Deductions**

# %%
df_plot_2 = df_uk_pay.to_pandas()

df_deductions = df_plot_2.melt(
    id_vars=['pay_date'],
    value_vars=['income_tax','national_insurance','pension_employee','gross_pay'],
    var_name='Deduction Type',
    value_name='Amount'
)

display(df_deductions)
# Out:
#      pay_date      Deduction Type   Amount
# 0  28/07/2025          income_tax   707.17
# 1  28/07/2025  national_insurance   282.87
# 2  28/07/2025    pension_employee   229.17
# 3  28/07/2025           gross_pay  4583.33

# %%
df_deductions['Deduction Type'] = df_deductions['Deduction Type'].replace({
    'income_tax':'Income Tax',
    'national_insurance':'National Insurance',
    'pension_employee':'Pension Insurance',
    'gross_pay':'Gross Pay'
})

fig_bar_2 = px.bar(
    df_deductions,
    x='pay_date',
    y='Amount',
    color='Deduction Type',
    barmode='group',
    labels={
        'pay_date':'Pay Date',
        'Amount':'Amount (£)',
        'Deduction Type':'type of Deduction',
        'income_tax':'Income Tax',
        'national_insurance':'National Insurance',
        'pension_employee':'Pension Insurance',
        'gross_pay':'Gross Pay'
    },
    color_discrete_sequence=px.colors.qualitative.Pastel,
    text_auto=True
)

fig_bar_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3850d148-b78c-4895-a967-3f4922e72737" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3850d148-b78c-4895-a967-3f4922e72737")) {                    Plotly.newPlot(                        "3850d148-b78c-4895-a967-3f4922e72737",                        [{"alignmentgroup":"True","hovertemplate":"type of Deduction=Income Tax\u003cbr\u003ePay Date=%{x}\u003cbr\u003eAmount (£)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Income Tax","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Income Tax","offsetgroup":"Income Tax","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[707.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type of Deduction=National Insurance\u003cbr\u003ePay Date=%{x}\u003cbr\u003eAmount (£)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"National Insurance","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"National Insurance","offsetgroup":"National Insurance","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[282.87],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type of Deduction=Pension Insurance\u003cbr\u003ePay Date=%{x}\u003cbr\u003eAmount (£)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pension Insurance","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Pension Insurance","offsetgroup":"Pension Insurance","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[229.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type of Deduction=Gross Pay\u003cbr\u003ePay Date=%{x}\u003cbr\u003eAmount (£)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gross Pay","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"Gross Pay","offsetgroup":"Gross Pay","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[4583.33],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66 ...

# %% [markdown]
# # **Breakdown of Deductions (Percentage)**

# %%
# Calculate Percentages with Polars

df_percent = df_uk_pay.with_columns([
    (pl.col('income_tax') / pl.col('gross_pay')* 100).alias('income_tax_pct'),
    (pl.col('national_insurance') / pl.col('gross_pay')* 100).alias('national_insurance_pct'),
    (pl.col('pension_employee') / pl.col('gross_pay')* 100).alias('pension_employee_pct'),
])

df_percent = df_percent.with_columns(
    (100 - (pl.col('income_tax_pct') + pl.col('national_insurance_pct')+ pl.col('pension_employee_pct'))).alias('Gross Pay (Net %)')
)

df_percent = df_percent.select([
    'pay_date',
    'Gross Pay (Net %)',
    'income_tax_pct',
    'national_insurance_pct',
    'pension_employee_pct'
])

df_percent_pd = df_percent.to_pandas()

# %%
# Preparing Data for Plotly (melt into long format)

df_melted = df_percent_pd.melt(
    id_vars=['pay_date'],
    value_vars=['Gross Pay (Net %)','income_tax_pct','national_insurance_pct','pension_employee_pct'],
    var_name='Component',
    value_name='Percentage'
)

label_map = {
    'Gross Pay (Net %)':'Gross Pay (Net %)',
    'income_tax_pct':'Income Tax (%)',
    'national_insurance_pct':'National Insurance (%)',
    'pension_employee_pct':'Pension Insurance (%)'
}

df_melted['Component'] = df_melted['Component'].map(label_map)

display(df_melted)
# Out:
#      pay_date               Component  Percentage
# 0  28/07/2025       Gross Pay (Net %)   73.399035
# 1  28/07/2025          Income Tax (%)   15.429175
# 2  28/07/2025  National Insurance (%)    6.171714
# 3  28/07/2025   Pension Insurance (%)    5.000076

# %%
fig_pct_deduction = px.bar(
    df_melted,
    x='pay_date',
    y='Percentage',
    color='Component',
    barmode='group',
    title='Monthly Deduction Breakdown (% of Gross Pay)',
    labels={
        'pay_date':'Pay Date',
        'Percentage':'Percentage (%)',
        'Component':'Type of Deduction',
    },
    color_discrete_sequence=px.colors.qualitative.Pastel,
    text_auto='.1f'
)

fig_pct_deduction.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f460730-aa67-45b1-9d72-7bc2aecea2a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f460730-aa67-45b1-9d72-7bc2aecea2a7")) {                    Plotly.newPlot(                        "9f460730-aa67-45b1-9d72-7bc2aecea2a7",                        [{"alignmentgroup":"True","hovertemplate":"Type of Deduction=Gross Pay (Net %)\u003cbr\u003ePay Date=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gross Pay (Net %)","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Gross Pay (Net %)","offsetgroup":"Gross Pay (Net %)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[73.39903519929832],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Deduction=Income Tax (%)\u003cbr\u003ePay Date=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Income Tax (%)","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Income Tax (%)","offsetgroup":"Income Tax (%)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[15.429174857581716],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Deduction=National Insurance (%)\u003cbr\u003ePay Date=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"National Insurance (%)","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"National Insurance (%)","offsetgroup":"National Insurance (%)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[6.171713579428058],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type of Deduction=Pension Insurance (%)\u003cbr\u003ePay Date=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pension Insurance (%)","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"Pension Insurance (%)","offsetgroup":"Pension Insurance (%)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":["28\u002f07\u002f2025"],"xaxis":"x","y":[5.000076363691901],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1 ...
